# %%
import pandas as pd 
import numpy as np

# %%
aep_data = pd.read_csv('../../../files/data1.csv') # Change the name to the name of your csv, but ensure it is in the

# %%
aep_data.head(50)
# Out:
#     OBSRVTN_NB      DATETIME_DTM  \
# 0       330560   3/15/2023 11:01
# 1       164330    7/9/2019 10:00
# 2       265239    8/1/2022 10:15
# 3       404438  10/18/2023 12:06
# 4        83172    3/3/2021 11:00
# 5       438962   2/22/2024 12:24
# 6       485230     8/5/2024 9:30
# 7        40409   6/24/2020 10:03
# 8       424794  12/28/2023 11:02
# 9       398234    9/27/2023 9:00
# 10      193121  10/28/2021 14:30
# 11      293699  10/14/2022 14:00
# 12      213377   2/17/2022 12:30
# 13      257116    7/7/2022 15:14
# 14       31740     8/3/2020 7:28
# 15       58914    10/7/2020 9:00
# 16       83755    3/5/2021 10:45
# 17      496094   9/19/2024 13:00
# 18      435990   2/13/2024 11:11
# 19      283550   9/28/2022 20:31
# 20      480032   7/22/2024 11:20
# 21      446181   3/20/2024 10:01
# 22      352420    5/18/2023 9:13
# 23      367850   6/29/2023 13:45
# 24      187287   11/3/2021 13:08
# 25      264287     8/2/2022 9:23
# 26      417781   11/29/2023 9:15
# ...

# %%
aep_data.describe()
# Out:
#          OBSRVTN_NB
# count  2.000000e+04
# mean   2.955562e+05
# std    4.879520e+05
# min    2.070000e+02
# 25%    1.656280e+05
# 50%    2.989210e+05
# 75%    4.210600e+05
# max    2.013241e+07

# %%
aep_data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Length: 20000, dtype: bool
